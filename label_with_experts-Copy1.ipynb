# %%
#essential libraries

#from google_drive import gdrive

from matplotlib.pyplot import show
import numpy as np
import pandas as pd
from scipy.cluster.vq import *
import operator
import matplotlib
reload(matplotlib)
#matplotlib.use('Agg')
from matplotlib import pyplot as plt
import pickle
import shelve
import re
from collections import Counter, defaultdict, OrderedDict, deque
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn import metrics
import scipy
from sklearn.feature_extraction import DictVectorizer
from matplotlib.backends.backend_pdf import PdfPages
import csv
import sys
import math
from copy import deepcopy, copy
import random
from datetime import datetime, timedelta
from operator import itemgetter
from itertools import chain
import os
import gc
import linecache
import multiprocessing
from functools import partial
from itertools import repeat
from IPython.display import clear_output
import json

import pprint
pp = pprint.PrettyPrinter()

import rdflib
from rdflib.namespace import OWL, RDF, RDFS
from rdflib import URIRef

from sklearn.ensemble import AdaBoostClassifier
from sklearn import preprocessing
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import BaggingClassifier
from sklearn.svm import OneClassSVM, SVC
from sklearn.mixture import GMM
from sklearn.mixture import DPGMM
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import MultinomialNB, BernoulliNB, GaussianNB
from sklearn.cluster import KMeans
from sklearn.tree import DecisionTreeClassifier
from sklearn.decomposition import PCA
from scipy.cluster.hierarchy import linkage, dendrogram
import scipy.cluster.hierarchy as hier
from scipy.cluster.hierarchy import fcluster
from scipy import spatial
from sklearn.multiclass import OneVsRestClassifier
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn import metrics
from scipy.cluster.hierarchy import linkage, dendrogram
import scipy.cluster.hierarchy as hier
from scipy import stats
from numpy.testing import assert_almost_equal

from scipy.spatial.distance import cosine as cosine_similarity

from divergence import gau_js as js_divergence
import brick_parser
reload(brick_parser)
from brick_parser import tagList, tagsetList, equipTagsetList, pointTagsetList, locationTagsetList,\
equalDict, pointTagList, equipTagList, locationTagList, equipPointDict
subTagListDict = dict([('point', pointTagList),
                          ('equip', equipTagList),
                          ('location', locationTagList)
                         ])
subTagsetListDict = dict([('point', pointTagsetList),
                          ('equip', equipTagsetList),
                          ('location', locationTagsetList)
                         ])

#from cmu_parser import cmu_building_parse

debugFlag = False
# Out:
# /home/jbkoh/anaconda2/lib/python2.7/site-packages/matplotlib/__init__.py:1350: UserWarning:  This call to matplotlib.use() has no effect
# because the backend has already been chosen;
# matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
#   warnings.warn(_use_error_msg)
# INFO:rdflib:RDFLib Version: 4.2.1
# Init Graph
# Load Brick.ttl
# Load BrickFrame.ttl
# Init Graph
# Load Brick.ttl
# Load BrickFrame.ttl

# %%
import building_tokenizer
reload(building_tokenizer)
import building_tokenizer as toker

buildingName = 'ebu3b'
notUcsdBuildings = ['ghc']

tokenType = 'NoNumber'
if not buildingName in notUcsdBuildings:
    naeDict = dict()
    naeDict['bonner'] = ["607", "608", "609", "557", "610"]
    naeDict['ap_m'] = ['514', '513','604']
    naeDict['bsb'] = ['519', '568', '567', '566', '564', '565']
    naeDict['ebu3b'] = ["505", "506"]
    #naeDict['otterson'] = ["518", "517", "589", "590"]
    naeList = naeDict[buildingName]

    labeledFile = 'metadata/' + buildingName + '_sensor_types_location.csv'
    with open(labeledFile, 'rb') as fp:
        #truthDF = pd.read_excel(fp)
        truthDF = pd.DataFrame.from_csv(fp)
        #truthDF = truthDF.set_index(keys='Unique Identifier')

    wordFeatFile = 'data/wordfeat_'+buildingName+'.pkl'

    tokenTypeList = ['NoNumber', 'Alphanumeric', 'AlphaAndNum', 'NumAsSingleWord']

    bacnetTypeMapDF = pd.DataFrame.from_csv('metadata/bacnettype_mapping.csv')
    unitMap = pd.read_csv('metadata/unit_mapping.csv').set_index('unit')
    for val in Counter(unitMap.keys()).values():
        if val>1:
            "Unit map file ERROR"
            assert(False)
            
            
    trueDF = pd.DataFrame.from_csv('metadata/'+buildingName+'_sensor_types_location.csv')
    sensorDF, nameList, jcinameList, descList, unitList, bacnettypeList, wordList = \
    toker.structure_metadata(buildingName=buildingName, tokenType=tokenType, \
                             validSrcidList=trueDF.index.tolist(), withDotFlag=False)

    origSensorDF = deepcopy(sensorDF)
    origNameList = deepcopy(nameList)
    origJcinameList = deepcopy(jcinameList)
    origDescList = deepcopy(descList)
    origUnitList = deepcopy(unitList)
    origBacnettypeList = deepcopy(bacnettypeList)
    origWordList = deepcopy(wordList)

    #_, rawNameList, rawJcinameList, rawDescList, _, _, _ = toker.structure_metadata(buildingName=buildingName, tokenType='AlphaAndNum', \
    _, rawNameList, rawJcinameList, rawDescList, _, _, _ =\
    toker.structure_metadata(buildingName=buildingName, tokenType='JustSeparate', \
                             validSrcidList=trueDF.index.tolist(), withDotFlag=False)
    
    
else: 
    filename = 'metadata/'+buildingName+'_sensor_types_location.csv'
    #   filename = 'metadata/%s_sensor_types_location.csv'%buildingName
    df = pd.read_csv(filename)
    sentenceDict = dict()    
    for i,raw in enumerate(df['bas_raw'].tolist()):
        sentenceDict[i] = toker.tokenize(tokenType, raw)
    
    
## Common part
    
#with open('data/'+buildingName+'_str_score_dict.pkl', 'rb') as fp:
#    scoreDictDict = pickle.load(fp)
#    ### If a word is exactly matched with another, fix it.
#    for word, scoreDict in scoreDictDict.items():
#        if word in scoreDict.keys():
#            scoreDictDict[word] = {word:1}
#    scoreDictDict['co'] = {'co2':1}
        
adder = lambda x,y:x+y
splitter = lambda x:x.split()
bacnetTypes = list(set(reduce(adder,map(splitter,origBacnettypeList),[])))
#for bacnetType in bacnetTypes:
#    scoreDictDict[bacnetType] = {bacnetType:1}
#units = list(set(unitMap['word'].tolist()))
#for unit in units:
#    if type(unit)==str:
#        scoreDictDict[unit] = {unit:1}

# %%
tagsetList
# Out:
# [u'temperature_alarm',
#  u'chiller_discharge_water_temperature_alarm',
#  u'chiller_supply_water_temperature_alarm',
#  u'maintenance_required_alarm',
#  u'condensate_leak_alarm',
#  u'emergency_generator_alarm',
#  u'high_humidity_alarm',
#  u'fume_hood_alarm',
#  u'communication_loss_alarm',
#  u'compressor_overload_alarm',
#  u'low_humidity_alarm',
#  u'low_suction_pressure_alarm',
#  u'supply_air_temperature_high_limit_alarm',
#  u'di_water_alarm',
#  u'discharge_air_temperature_high_limit_alarm',
#  u'failure_alarm',
#  u'chiller_failure_alarm',
#  u'return_air_temperature_low_limit_alarm',
#  u'high_temperature_alarm',
#  u'low_temperature_alarm',
#  u'liquid_detected_alarm',
#  u'deionised_water_alarm',
#  u'co2_high_alarm',
#  u'discharge_air_smoke_detected_alarm',
#  u'high_head_pressure_alarm',
#  u'supply_air_smoke_detected_alarm',
#  u'change_filter_alarm',
#  u'short_cycle_alarm',
#  u'power_loss_alarm',
#  u'humidifier_alarm',
#  u'smoke_detected_alarm',
#  u'air_flow_loss_alarm',
#  u'water_loss_alarm',
#  u'pump_alarm',
#  u'return_air_temperature_high_limit_alarm',
#  u'fan_overload_alarm',
#  u'emergency_power_loss_alarm',
#  u'luminance_alarm',
#  u'unit_failed_alarm',
#  u'hot_water_pump_alarm',
#  u'humidifier_panel_no_water_alarm',
#  u'vfd_alarm',
#  u'shutdown_command',
#  u'system_shutdown_command',
#  u'shutdown_hot_water_when_unoccupied_command',
#  u'override_command',
#  u'curtailment_override_command',
#  u'luminance_command',
#  u'humidify_command',
#  u'enable_command',
#  u'chilled_water_system_enable_command',
#  u'exhaust_fan_enable_command',
#  u'hot_water_system_enable_command',
#  u'system_enable_command',
#  u'vfd_enable_command',
#  u'domestic_hot_water_system_enable_command',
#  u'exhaust_fan_system_enable_command',
#  u'run_enable_command',
#  u'direction_command',
#  u'run_direction_command',
#  u'motor_direction_command',
#  u'frequency_command',
#  u'max_frequency_command',
#  u'pump_command',
#  u'chilled_water_pump_command',
#  u'pump_lead_lag_command',
#  u'hot_water_pump_lead_lag_command',
#  u'chilled_water_pump_lead_lag_command',
#  u'pump_lead_on_off_command',
#  u'emergency_power_off_command',
#  u'heating_command',
#  u'supply_air_flow_command',
#  u'disable_command',
#  u'exhaust_fan_disable_command',
#  u'occupancy_command',
#  u'emergency_power_off_switch_command',
#  u'load_shed_command',
#  u'standby_load_shed_command',
#  u'zone_standby_load_shed_command',
#  u'unoccupied_load_shed_command',
#  u'zone_unoccupied_load_shed_command',
#  u'mode_command',
#  u'box_mode_command',
#  u'maintenance_mode_command',
#  u'automatic_mode_command',
#  u'damper_command',
#  u'mixed_air_damper_position_command',
#  u'exhaust_bypass_damper_command',
#  u'economizer_damper_command',
#  u'outside_air_damper_position_command',
#  u'reset_command',
#  u'fan_speed_reset_command',
#  u'speed_reset_command',
#  u'filter_reset_command',
#  u'fault_reset_command',
#  u'cooling_command',
#  u'highest_zone_cooling_command',
#  u'fans_stage_command',
#  u'building_exhaust_fans_stage_command',
#  u'start_stop_command',
#  u'domestic_hot_water_system_start_stop_command',
#  u'motor_start_stop_command',
#  u'discharge_fan_start_stop_command',
#  u'hot_water_pump_start_stop_command',
#  u'chilled_water_pump_start_stop_command',
#  u'exhaust_fan_start_stop_command',
#  u'supply_fan_start_stop_command',
#  u'booster_fan_start_stop_command',
#  u'return_fan_start_stop_command',
#  u'heat_exchanger_start_stop_command',
#  u'pump_start_stop_command',
#  u'valve_command',
#  u'preheat_valve_command',
#  u'return_air_preheat_valve_command',
#  u'heating_valve_command',
#  u'return_heat_valve_command',
#  u'domestic_hot_water_valve_command',
#  u'perimeter_heating_valve_command',
#  u'hot_water_valve_command',
#  u'reheat_valve_command',
#  u'heat_exchanger_valve_command',
#  u'chilled_water_bypass_valve_command',
#  u'cooling_valve_command',
#  u'booster_command',
#  u'booster_fan_command',
#  u'discharge_air_flow_command',
#  u'on_off_command',
#  u'steam_on_off_command',
#  u'fire_control_panel_command',
#  u'exhaust_fan_fire_control_panel_on_command',
#  u'fire_control_panel_off_command',
#  u'fire_control_panel_on_command',
#  u'exhaust_fan_fire_control_panel_off_command',
#  u'panel_lockout_command',
#  u'occupied_command',
#  u'fan_command',
#  u'return_fan_command',
#  u'discharge_fan_command',
#  u'supply_fan_command',
#  u'exhaust_fan_command',
#  u'request_command',
#  u'run_request_command',
#  u'vfd_speed_command',
#  u'supply_fan_vfd_speed_command',
#  u'hot_water_pump_vfd_speed_command',
#  u'exhaust_fan_vfd_speed_command',
#  u'discharge_fan_vfd_speed_command',
#  u'return_fan_vfd_speed_command',
#  u'chilled_water_pump_vfd_speed_command',
#  u'energy_meter',
#  u'peak_energy_today_meter',
#  u'flow_meter',
#  u'hot_water_flow_meter',
#  u'power_meter',
#  u'electrical_power_meter',
#  u'thermal_power_meter',
#  u'heating_thermal_power_meter',
#  u'cooling_thermal_power_meter',
#  u'motor_power_meter',
#  u'gas_meter',
#  u'steam_usage_meter',
#  u'monthly_steam_usage_meter',
#  u'steam_usage_today_meter',
#  u'yearly_steam_usage_meter',
#  u'current_steam_usage_meter',
#  u'water_meter',
#  u'hot_water_meter',
#  u'chilled_water_meter',
#  u'angle_sensor',
#  u'solar_azimuth_angle_sensor',
#  u'solar_zenith_angle_sensor',
#  u'co2_level_sensor',
#  u'rain_sensor',
#  u'co2_sensor',
#  u'outside_air_co2_sensor',
#  u'return_air_co2_sensor',
#  u'warm_cool_adjust_sensor',
#  u'hail_sensor',
#  u'timer_sensor',
#  u'on_timer_sensor',
#  u'water_level_sensor',
#  u'deionised_water_level_sensor',
#  u'di_water_level_sensor',
#  u'humidity_sensor',
#  u'exhaust_air_humidity_sensor',
#  u'relative_humidity_sensor',
#  u'return_air_humidity_sensor',
#  u'outside_air_humidity_sensor',
#  u'discharge_air_humidity_sensor',
#  u'supply_air_humidity_sensor',
#  u'zone_humidity_sensor',
#  u'temperature_sensor',
#  u'zone_temperature_sensor',
#  u'coldest_zone_temperature_sensor',
#  u'average_zone_temperature_sensor',
#  u'lowest_zone_temperature_sensor',
#  u'warmest_zone_temperature_sensor',
#  u'highest_zone_temperature_sensor',
#  u'cooling_coil_discharge_air_temperature_sensor',
#  u'water_supply_temperature_sensor',
#  u'chilled_water_temperature_differential_sensor',
#  u'supply_water_temperature_sensor',
#  u'chilled_water_discharge_temperature_sensor',
#  u'heat_exchanger_supply_water_temperature_sensor',
#  u'hot_water_supply_temperature_sensor',
#  u'domestic_hot_water_discharge_temperature_sensor',
#  u'high_temperature_hot_water_discharge_temperature_sensor',
#  u'medium_temperature_hot_water_discharge_temperature_sensor',
#  u'high_temperature_hot_water_supply_temperature_sensor',
#  u'domestic_hot_water_supply_temperature_sensor',
#  u'medium_temperature_hot_water_supply_temperature_sensor',
#  u'chilled_water_supply_temperature_sensor',
#  u'hot_water_discharge_temperature_sensor',
#  u'heat_exchanger_discharge_water_temperature_sensor',
#  u'underfloor_temperature_sensor',
#  u'room_temperature_sensor',
#  u'environment_box_temperature_sensor',
#  u'return_water_temperature_sensor',
#  u'hot_water_return_temperature_sensor',
#  u'high_temperature_hot_water_return_temperature_sensor',
#  u'medium_temperature_hot_water_return_temperature_sensor',
#  u'chilled_water_return_temperature_sensor',
#  u'mixed_air_temperature_sensor',
#  u'exhaust_air_temperature_sensor',
#  u'zone_air_temperature_sensor',
#  u'differential_temperature_sensor',
#  u'condensor_temperature_sensor',
#  u'entering_water_temperature_sensor',
#  u'preheat_coil_entering_air_temperature_sensor',
#  u'hot_water_coil_entering_temperature_sensor',
#  u'ice_tank_entering_water_temperature_sensor',
#  u'hot_box_temperature_sensor',
#  u'supply_air_temperature_sensor',
#  u'freezer_temperature_sensor',
#  u'crac_temperature_sensor',
#  u'discharge_air_temperature_sensor',
#  u'preheat_discharge_air_temperature_sensor',
#  u'outside_air_temperature_sensor',
#  u'leaving_water_temperature_sensor',
#  u'ice_tank_leaving_water_temperature_sensor',
#  u'preheat_coil_leaving_water_temperature_sensor',
#  u'drive_temperature_sensor',
#  u'water_discharge_temperature_sensor',
#  u'cooling_coil_supply_air_temperature_sensor',
#  u'preheat_supply_air_temperature_sensor',
#  u'outside_air_lockout_temperature_differential_sensor',
#  u'return_air_temperature_sensor',
#  u'cold_box_temperature_sensor',
#  u'low_outside_air_temperature_enable_differential_sensor',
#  u'heat_wheel_supply_air_temperature_sensor',
#  u'heat_wheel_discharge_air_temperature_sensor',
#  u'frequency_sensor',
#  u'output_frequency_sensor',
#  u'air_grains_sensor',
#  u'return_air_grains_sensor',
#  u'outside_air_grains_sensor',
#  u'average_cooling_demand_sensor',
#  u'occupancy_sensor',
#  u'dewpoint_sensor',
#  u'outside_air_dewpoint_sensor',
#  u'return_air_dewpoint_sensor',
#  u'speed_sensor',
#  u'wind_speed_sensor',
#  u'differential_speed_sensor',
#  u'return_fan_differential_speed_sensor',
#  u'heat_wheel_speed_sensor',
#  u'motor_speed_sensor',
#  u'voltage_sensor',
#  u'heat_wheel_voltage_sensor',
#  u'dc_bus_voltage_sensor',
#  u'output_voltage_sensor',
#  u'battery_voltage_sensor',
#  u'thermostat_adjust_sensor',
#  u'demand_sensor',
#  u'peak_power_demand_sensor',
#  u'running_hour_sensor',
#  u'enthalpy_sensor',
#  u'return_air_enthalpy_sensor',
#  u'outside_enthalpy_sensor',
#  u'outside_air_enthalpy_sensor',
#  u'pressure_sensor',
#  u'valve_pressure_sensor',
#  u'chilled_valve_pressure_sensor',
#  u'differential_pressure_sensor',
#  u'filter_differential_pressure_sensor',
#  u'hot_water_differential_pressure_sensor',
#  u'medium_temperature_hot_water_differential_pressure_sensor',
#  u'chilled_water_differential_pressure_sensor',
#  u'heat_wheel_differential_pressure_sensor',
#  u'cooling_coil_valve_pressure_sensor',
#  u'static_pressure_sensor',
#  u'supply_air_static_pressure_sensor',
#  u'building_static_pressure_sensor',
#  u'exhaust_air_static_pressure_sensor',
#  u'lowest_exhaust_air_static_pressure_sensor',
#  u'average_exhaust_air_static_pressure_sensor',
#  u'discharge_air_static_pressure_sensor',
#  u'velocity_pressure_sensor',
#  u'exhaust_air_velocity_pressure_sensor',
#  u'supply_air_velocity_pressure_sensor',
#  u'discharge_air_velocity_pressure_sensor',
#  u'trace_heat_sensor',
#  u'piezoelectric_sensor',
#  u'supply_fan_piezoelectric_sensor',
#  u'exhaust_fan_piezoelectric_sensor',
#  u'discharge_fan_piezoelectric_sensor',
#  u'torque_sensor',
#  u'motor_torque_sensor',
#  u'direction_sensor',
#  u'wind_direction_sensor',
#  u'co2_differential_sensor',
#  u'damper_position_sensor',
#  u'fume_hood_sash_position_sensor',
#  u'outside_air_damper_position_sensor',
#  u'bypass_damper_position_sensor',
#  u'mixed_air_damper_position_sensor',
#  u'solar_radiance_sensor',
#  u'current_sensor',
#  u'load_current_sensor',
#  u'photovoltaic_current_output_sensor',
#  u'motor_current_sensor',
#  u'pv_current_output_sensor',
#  u'conductivity_sensor',
#  u'deionised_water_conductivity_sensor',
#  u'flow_sensor',
#  u'water_flow_sensor',
#  u'supply_water_flow_sensor',
#  u'chilled_water_supply_flow_sensor',
#  u'chilled_water_discharge_flow_sensor',
#  u'air_flow_sensor',
#  u'fume_hood_air_flow_sensor',
#  u'discharge_air_flow_sensor',
#  u'average_discharge_air_flow_sensor',
#  u'average_supply_air_flow_sensor',
#  u'outside_air_flow_sensor',
#  u'return_air_flow_sensor',
#  u'supply_air_flow_sensor',
#  u'exhaust_air_flow_sensor',
#  u'exhaust_air_stack_flow_sensor',
#  u'bypass_air_flow_sensor',
#  u'fan_air_flow_sensor',
#  u'return_fan_air_flow_sensor',
#  u'discharge_fan_air_flow_sensor',
#  u'booster_fan_air_flow_sensor',
#  u'supply_fan_air_flow_sensor',
#  u'vfd_speed_sensor',
#  u'supply_fan_vfd_speed_sensor',
#  u'return_fan_vfd_speed_sensor',
#  u'discharge_fan_vfd_speed_sensor',
#  u'outside_luminance_sensor',
#  u'rain_duration_sensor',
#  u'energy_sensor',
#  u'frost_sensor',
#  u'luminance_sensor',
#  u'motion_sensor',
#  u'pir_sensor',
#  u'run_time_sensor',
#  u'capacity_sensor',
#  u'hold_status',
#  u'pressure_status',
#  u'supply_air_duct_pressure_status',
#  u'discharge_air_duct_pressure_status',
#  u'direction_status',
#  u'motor_direction_status',
#  u'run_direction_status',
#  u'emergency_power_off_status',
#  u'emergency_power_off_activated_by_leak_detection_system_status',
#  u'emergency_power_off_system_enable_status',
#  u'emergency_power_off_activated_by_high_temperature_status',
#  u'emergency_power_off_enable_status',
#  u'vfd_speed_status',
#  u'supply_fan_vfd_speed_status',
#  u'return_fan_vfd_speed_status',
#  u'discharge_fan_vfd_speed_status',
#  u'vfd_status',
#  u'start_stop_status',
#  u'discharge_fan_start_stop_status',
#  u'exhaust_fan_start_stop_status',
#  u'motor_start_stop_status',
#  u'pump_start_stop_status',
#  u'chilled_water_pump_start_stop_status',
#  u'fan_start_stop_status',
#  u'run_status',
#  u'pump_status',
#  u'chilled_water_pump_status',
#  u'hot_water_pump_status',
#  u'return_fan_start_stop_status',
#  u'supply_fan_start_stop_status',
#  u'turn_off_status',
#  u'load_shed_status',
#  u'differential_pressure_load_shed_status',
#  u'medium_temperature_hot_water_differential_pressure_load_shed_reset_status',
#  u'chilled_water_differential_pressure_load_shed_reset_status',
#  u'medium_temperature_hot_water_differential_pressure_load_shed_status',
#  u'chilled_water_differential_pressure_load_shed_status',
#  u'medium_temperature_hot_water_supply_temperature_load_shed_status',
#  u'medium_temperature_hot_water_discharge_temperature_load_shed_status',
#  u'emergency_push_button_status',
#  u'disable_status',
#  u'exhaust_fan_disable_status',
#  u'fan_status',
#  u'supply_fan_status',
#  u'exhaust_fan_status',
#  u'return_fan_status',
#  u'standby_fan_status',
#  u'discharge_fan_status',
#  u'on_off_status',
#  u'econcycle_on_off_status',
#  u'dehumidification_on_off_status',
#  u'standby_unit_on_off_status',
#  u'heating_on_off_status',
#  u'locally_on_off_status',
#  u'cooling_on_off_status',
#  u'humidification_on_off_status',
#  u'remotely_on_off_status',
#  u'stages_status',
#  u'fire_control_panel_led_status',
#  u'exhaust_fan_off_status_led',
#  u'ahu_on_status_led',
#  u'ahu_off_status_led',
#  u'exhaust_fan_on_status_led',
#  u'fault_indicator_status',
#  u'system_status',
#  u'hand_auto_status',
#  u'emergency_air_flow_status',
#  u'occupancy_status',
#  u'temporary_occupancy_status',
#  u'drive_ready_status',
#  u'pump_lead_lag_status',
#  u'chilled_water_pump_lead_lag_status',
#  u'even_month_status',
#  u'enable_status',
#  u'run_enable_status',
#  u'chilled_water_pump_enable_status',
#  u'heat_exchanger_system_enable_status',
#  u'pump_enable_status',
#  u'last_fault_code_status',
#  u'manual_auto_status',
#  u'fault_status',
#  u'humidifier_fault_status',
#  u'valve_status',
#  u'heat_exchanger_valve_status',
#  u'freeze_status',
#  u'mode_status',
#  u'vent_operating_mode_status',
#  u'vav_box_operating_mode_status',
#  u'economizer_mode_status',
#  u'system_mode_status',
#  u'occupied_mode_status',
#  u'economizer_status',
#  u'fan_run_request_status',
#  u'emergency_generator_status',
#  u'filter_status',
#  u'pre_filter_status',
#  u'overridden_status',
#  u'overridden_off_status',
#  u'overridden_on_status',
#  u'exhaust_fan_overridden_off_status',
#  u'exhaust_fan_overridden_on_status',
#  u'system_shutdown_status',
#  u'co2_setpoint',
#  u'return_air_co2_setpoint',
#  u'max_return_air_co2_setpoint',
#  u'mode_setpoint',
#  u'unoccupied_mode_setpoint',
#  u'dualband_mode_setpoint',
#  u'flow_setpoint',
#  u'acceleration_time_setpoint',
#  u'vfd_speed_setpoint',
#  u'max_vfd_speed_setpoint',
#  u'supply_fan_vfd_speed_setpoint',
#  u'discharge_fan_vfd_speed_setpoint',
#  u'min_vfd_speed_setpoint',
#  u'return_fan_vfd_speed_setpoint',
#  u'alarm_delay_setpoint',
#  u'pump_alarm_delay_setpoint',
#  u'chilled_water_pump_alarm_delay_setpoint',
#  u'luminance_setpoint',
#  u'demand_setpoint',
#  u'heating_demand_setpoint',
#  u'supply_air_flow_demand_setpoint',
#  u'preheat_demand_setpoint',
#  u'heating_request_percent_setpoint',
#  u'cooling_request_percent_setpoint',
#  u'discharge_air_flow_demand_setpoint',
#  u'cooling_demand_setpoint',
#  u'cooling_request_setpoint',
#  u'heating_request_setpoint',
#  u'current_limit_setpoint',
#  u'rated_speed_setpoint',
#  u'enthalpy_setpoint',
#  u'economizer_enthalpy_setpoint',
#  u'economizer_disable_differential_enthalpy_setpoint',
#  u'economizer_enable_differential_enthalpy_setpoint',
#  u'economizer_disable_fixed_enthalpy_setpoint',
#  u'economizer_enable_fixed_enthalpy_setpoint',
#  u'proportional_band_setpoint',
#  u'supply_water_temperature_proportional_band_setpoint',
#  u'heat_exchanger_supply_water_temperature_proportional_band_setpoint',
#  u'heat_exchanger_discharge_water_temperature_proportional_band_setpoint',
#  u'discharge_air_static_pressure_proportional_band_setpoint',
#  u'heating_discharge_air_temperature_proportional_band_setpoint',
#  u'economizer_discharge_air_temperature_proportional_band_setpoint',
#  u'differential_pressure_proportional_band',
#  u'chilled_water_pump_differential_pressure_proportional_band_setpoint',
#  u'cooling_discharge_air_temperature_proportional_band_setpoint',
#  u'supply_water_differential_pressure_proportional_band_setpoint',
#  u'thermal_energy_storage_supply_water_differential_pressure_proportional_band_setpoint',
#  u'thermal_energy_storage_discharge_water_differential_pressure_proportional_band_setpoint',
#  u'cooling_supply_air_temperature_proportional_band_setpoint',
#  u'economizer_supply_air_temperature_proportional_band_setpoint',
#  u'differential_pressure_proportional_band_setpoint',
#  u'hot_water_differential_pressure_proportional_band_setpoint',
#  u'exhaust_air_flow_proportional_band_setpoint',
#  u'exhaust_air_stack_flow_proportional_band_setpoint',
#  u'chilled_water_differential_pressure_proportional_band_setpoint',
#  u'supply_air_static_pressure_proportional_band_setpoint',
#  u'static_pressure_proportional_band_setpoint',
#  u'exhaust_air_static_pressure_proportional_band_setpoint',
#  u'heating_supply_air_temperature_proportional_band_setpoint',
#  u'integral_time_setpoint',
#  u'discharge_air_static_pressure_integral_time_setpoint',
#  u'supply_water_temperature_integral_time_setpoint',
#  u'heat_exchanger_discharge_water_temperature_integral_time_setpoint',
#  u'heat_exchanger_supply_water_temperature_integral_time_setpoint',
#  u'static_pressure_integral_time_setpoint',
#  u'exhaust_air_static_pressure_integral_time_setpoint',
#  u'exhaust_air_flow_integral_time_setpoint',
#  u'exhaust_air_stack_flow_integral_time_setpoint',
#  u'differential_pressure_integral_time_setpoint',
#  u'hot_water_differential_pressure_integral_time_setpoint',
#  u'supply_air_static_pressure_integral_time_setpoint',
#  u'supply_water_differential_pressure_integral_time_setpoint',
#  u'thermal_energy_storage_discharge_water_differential_pressure_integral_time_setpoint',
#  u'thermal_energy_storage_supply_water_differential_pressure_integral_time_setpoint',
#  u'heating_discharge_air_temperature_integral_time_setpoint',
#  u'heating_supply_air_temperature_integral_time_setpoint',
#  u'cooling_supply_air_temperature_integral_time_setpoint',
#  u'differential_pressure_integral_time',
#  u'chilled_water_pump_differential_pressure_integration_time_setpoint',
#  u'cooling_discharge_air_temperature_integral_time_setpoint',
#  u'chilled_water_differential_pressure_integral_time_setpoint',
#  u'min_fresh_air_setpoint',
#  u'high_temperature_alarm_setpoint',
#  u'humidity_setpoint',
#  u'low_humidity_alarm_setpoint',
#  u'dew_point_setpoint',
#  u'economizer_dewpoint_setpoint',
#  u'economizer_disable_fixed_dewpoint_setpoint',
#  u'economizer_enable_fixed_dewpoint_setpoint',
#  u'speed_setpoint',
#  u'differential_speed_setpoint',
#  u'return_supply_fan_differential_speed_setpoint',
#  u'return_fan_differential_speed_setpoint',
#  u'return_discharge_fan_differential_speed_setpoint',
#  u'fan_speed_setpoint',
#  u'cooling_tower_fan_speed_setpoint',
#  u'temperature_setpoint',
#  u'heating_temperature_setpoint',
#  u'effective_heating_temperature_setpoint',
#  u'occupied_heating_temperature_setpoint',
#  u'unoccupied_heating_temperature_setpoint',
#  u'discharge_air_temperature_cooling_setpoint',
#  u'open_heating_valve_outside_air_temperature_setpoint',
#  u'economizer_temperature_setpoint',
#  u'economizer_disable_differential_temperature_setpoint',
#  u'economizer_enable_fixed_temperature_setpoint',
#  u'economizer_disable_fixed_temperature_setpoint',
#  u'economizer_enable_differential_temperature_setpoint',
#  u'room_temperature_setpoint',
#  u'schedule_temperature_setpoint',
#  u'min_discharge_air_temperature_setpoint',
#  u'discharge_air_temperature_setpoint',
#  u'supply_water_temperature_setpoint',
#  u'hot_water_supply_temperature_setpoint',
#  u'domestic_hot_water_supply_temperature_setpoint',
#  u'domestic_hot_water_discharge_temperature_setpoint',
#  u'heat_exchanger_supply_water_temperature_setpoint',
#  u'load_shed_supply_water_temperature_setpoint',
#  u'medium_temperature_hot_water_discharge_temperature_load_shed_setpoint',
#  u'medium_temperature_hot_water_supply_temperature_load_shed_setpoint',
#  u'heat_exchanger_discharge_water_temperature_setpoint',
#  u'discharge_water_temperature_setpoint',
#  u'enable_hot_water_system_outside_air_temperature_setpoint',
#  u'temperature_low_limit_setpoint',
#  u'freeze_protect_temperature_low_limit_setpoint',
#  u'thumbwheel_temperature_low_limit_setpoint',
#  u'mixed_air_temperature_setpoint',
#  u'temperature_high_limit_setpoint',
#  u'thumbwheel_temperature_high_limit_setpoint',
#  u'discharge_air_temperature_heating_setpoint',
#  u'min_supply_air_temperature_setpoint',
#  u'supply_air_temperature_setpoint',
#  u'low_outside_air_temperature_enable_setpoint',
#  u'supply_air_temperature_cooling_setpoint',
#  u'low_temperature_alarm_setpoint',
#  u'supply_air_temperature_heating_setpoint',
#  u'zone_temperature_setpoint',
#  u'zone_temperature_high_setpoint',
#  u'zone_cooling_temperature_setpoint',
#  u'zone_heating_temperature_setpoint',
#  u'zone_temperature_low_setpoint',
#  u'economizer_differential_air_temperature_setpoint',
#  u'outside_air_lockout_temperature_setpoint',
#  u'max_supply_air_temperature_setpoint',
#  u'cooling_temperature_setpoint',
#  u'auto_cooling_temperature_setpoint',
#  u'unoccupied_cooling_temperature_setpoint',
#  u'current_cooling_setpoint',
#  u'effective_cooling_temperature_setpoint',
#  u'occupied_cooling_temperature_setpoint',
#  u'max_discharge_air_temperature_setpoint',
#  u'disable_hot_water_system_outside_air_temperature_setpoint',
#  u'reset_setpoint',
#  u'temperature_high_reset_setpoint',
#  u'outside_air_temperature_high_reset_setpoint',
#  u'hot_water_supply_temperature_high_reset_setpoint',
#  u'medium_temperature_hot_water_supply_temperature_high_reset_setpoint',
#  u'medium_temperature_hot_water_discharge_temperature_high_reset_setpoint',
#  u'discharge_air_temperature_reset_high_setpoint',
#  u'flow_high_reset_setpoint',
#  u'discharge_air_flow_reset_high_setpoint',
#  u'supply_air_temperature_reset_low_setpoint',
#  u'temperature_differential_reset_setpoint',
#  u'discharge_air_temperature_reset_differential_setpoint',
#  u'supply_air_temperature_reset_differential_setpoint',
#  u'flow_low_reset_setpoint',
#  u'discharge_air_flow_reset_low_setpoint',
#  u'temperature_low_reset_setpoint',
#  u'outside_air_temperature_low_reset_setpoint',
#  u'hot_water_supply_temperature_low_reset_setpoint',
#  u'medium_temperature_hot_water_discharge_temperature_low_reset_setpoint',
#  u'medium_temperature_hot_water_supply_temperature_low_reset_setpoint',
#  u'discharge_air_temperature_reset_low_setpoint',
#  u'supply_air_temperature_reset_high_setpoint',
#  u'integral_gain_setpoint',
#  u'supply_air_integrative_gain_factor',
#  u'increase_decrease_step_setpoint',
#  u'discharge_air_static_pressure_increase_decrease_step_setpoint',
#  u'supply_air_temperature_setpoint_increase_decrease_step',
#  u'chilled_water_differential_pressure_increase_decrease_step_setpoint',
#  u'discharge_air_temperature_setpoint_increase_decrease_step',
#  u'supply_air_static_pressure_increase_decrease_step_setpoint',
#  u'load_setpoint',
#  u'max_load_setpoint',
#  u'chiller_max_load_setpoint',
#  u'air_flow_setpoint',
#  u'supply_air_flow_setpoint',
#  u'ventilation_air_flow_ratio_limit_setpoint',
#  u'economizer_outside_air_flow_setpoint',
#  u'exhaust_air_flow_setpoint',
#  u'exhaust_air_stack_flow_setpoint',
#  u'outside_min_air_flow_setpoint',
#  u'fan_air_flow_setpoint',
#  u'booster_fan_air_flow_setpoint',
#  u'exhaust_fan_air_flow_setpoint',
#  u'discharge_air_flow_setpoint',
#  u'cooling_discharge_air_flow_setpoint',
#  u'cooling_max_discharge_air_flow_setpoint',
#  u'occupied_cooling_supply_air_flow_setpoint',
#  u'cooling_min_supply_air_flow_setpoint',
#  u'unoccupied_cooling_discharge_air_flow_setpoint',
#  u'cooling_max_supply_air_flow_setpoint',
#  u'cooling_min_discharge_air_flow_setpoint',
#  u'occupied_cooling_discharge_air_flow_setpoint',
#  u'occupied_cooling_min_supply_air_flow_setpoint',
#  u'occupied_cooling_max_supply_air_flow_setpoint',
#  u'occupied_cooling_min_discharge_air_flow_setpoint',
#  u'occupied_cooling_max_discharge_air_flow_setpoint',
#  u'unoccupied_cooling_supply_air_flow_setpoint',
#  u'heating_discharge_air_flow_setpoint',
#  u'heating_min_supply_air_flow_setpoint',
#  u'heating_max_discharge_air_flow_setpoint',
#  u'occupied_heating_supply_air_flow_setpoint',
#  u'heating_max_supply_air_flow_setpoint',
#  u'heating_min_discharge_air_flow_setpoint',
#  u'occupied_heating_discharge_air_flow_setpoint',
#  u'occupied_heating_max_discharge_air_flow_setpoint',
#  u'occupied_heating_min_supply_air_flow_setpoint',
#  u'occupied_heating_max_supply_air_flow_setpoint',
#  u'occupied_heating_min_discharge_air_flow_setpoint',
#  u'heating_supply_air_flow_setpoint',
#  u'damper_position_setpoint',
#  u'discharge_air_damper_max_position_setpoint',
#  u'supply_air_damper_max_position_setpoint',
#  u'outside_air_damper_close_limit_setpoint',
#  u'outside_air_damper_min_position_setpoint',
#  u'economizer_damper_min_position_setpoint',
#  u'tolerance_setpoint',
#  u'humidity_tolerance_setpoint',
#  u'temperature_tolerance_setpoint',
#  u'high_humidity_alarm_setpoint',
#  u'pressure_setpoint',
#  u'static_pressure_setpoint',
#  u'building_static_pressure_setpoint',
#  u'high_static_pressure_cutout_limit_setpoint',
#  u'static_pressure_max_setpoint',
#  u'exhaust_air_static_pressure_setpoint',
#  u'hot_water_static_pressure_setpoint',
#  u'static_pressure_min_setpoint',
#  u'discharge_air_static_pressure_setpoint',
#  u'min_discharge_air_static_pressure_setpoint',
#  u'min_supply_air_static_pressure_setpoint',
#  u'max_supply_air_static_pressure_setpoint',
#  u'max_discharge_air_static_pressure_setpoint',
#  u'supply_air_static_pressure_setpoint',
#  u'chilled_water_static_pressure_setpoint',
#  u'differential_pressure_setpoint',
#  u'load_shed_differential_pressure_setpoint',
#  u'medium_temperature_hot_water_differential_pressure_load_shed_setpoint',
#  u'chilled_water_differential_pressure_load_shed_setpoint',
#  u'hot_water_differential_pressure_setpoint',
#  u'chilled_water_differential_pressure_setpoint',
#  u'min_chilled_water_differential_pressure_setpoint',
#  u'max_chilled_water_differential_pressure_setpoint',
#  u'velocity_pressure_setpoint',
#  u'dead_band_setpoint',
#  u'differential_pressure_dead_band_setpoint',
#  u'hot_water_differential_pressure_dead_band_setpoint',
#  u'chilled_water_pump_differential_pressure_dead_band_setpoint',
#  u'chilled_water_differential_pressure_dead_band_setpoint',
#  u'exhaust_air_flow_dead_band_setpoint',
#  u'exhaust_air_stack_flow_dead_band_setpoint',
#  u'heating_supply_air_temperature_dead_band_setpoint',
#  u'economizer_supply_air_temperature_dead_band_setpoint',
#  u'cooling_supply_air_temperature_dead_band_setpoint',
#  u'heating_discharge_air_temperature_dead_band_setpoint',
#  u'supply_water_differential_pressure_dead_band_setpoint',
#  u'thermal_energy_storage_supply_water_differential_pressure_dead_band_setpoint',
#  u'thermal_energy_storage_discharge_water_differential_pressure_dead_band_setpoint',
#  u'zone_cooling_temperature_dead_band_setpoint',
#  u'occupied_cooling_temperature_dead_band_setpoint',
#  u'static_pressure_dead_band_setpoint',
#  u'discharge_air_static_pressure_dead_band_setpoint',
#  u'exhaust_air_static_pressure_dead_band_setpoint',
#  u'supply_air_static_pressure_dead_band_setpoint',
#  u'economizer_discharge_air_temperature_dead_band_setpoint',
#  u'zone_heating_temperature_dead_band_setpoint',
#  u'occupied_heating_temperature_dead_band_setpoint',
#  u'cooling_discharge_air_temperature_dead_band_setpoint',
#  u'supply_water_temperature_dead_band_setpoint',
#  u'heat_exchanger_supply_water_temperature_dead_band_setpoint',
#  u'heat_exchanger_discharge_water_temperature_dead_band_setpoint',
#  u'proportional_gain_setpoint',
#  u'supply_air_proportional_gain_factor',
#  u'deceleration_time_setpoint',
#  u'discharge_water_temperature_sensor',
#  u'discharge_water_flow_sensor',
#  u'discharge_water_temperature_proportional_band_setpoint',
#  u'discharge_water_differential_pressure_proportional_band_setpoint',
#  u'discharge_water_temperature_integral_time_setpoint',
#  u'discharge_water_differential_pressure_integral_time_setpoint',
#  u'hot_water_discharge_temperature_setpoint',
#  u'load_shed_discharge_water_temperature_setpoint',
#  u'hot_water_discharge_temperature_high_reset_setpoint',
#  u'supply_air_flow_reset_high_setpoint',
#  u'supply_air_flow_reset_low_setpoint',
#  u'hot_water_discharge_temperature_low_reset_setpoint',
#  u'discharge_air_integrative_gain_factor',
#  u'cooling_supply_air_flow_setpoint',
#  u'discharge_water_differential_pressure_dead_band_setpoint',
#  u'discharge_water_temperature_dead_band_setpoint',
#  u'discharge_air_proportional_gain_factor',
#  u'fire_safety_system',
#  u'fire_control_panel',
#  u'water_system',
#  u'cooling_coil',
#  u'chiller',
#  u'cooling_tower_fan',
#  u'cooling_tower',
#  u'domestic_hot_water_system',
#  u'chilled_water_system',
#  u'hot_water_system',
#  u'elevator',
#  u'solar_panel',
#  u'steam',
#  u'power_system',
#  u'inverter',
#  u'emergency_generator',
#  u'demand_response',
#  u'hvac',
#  u'compressor',
#  u'ahu',
#  u'preheat_valve_vfd',
#  u'preheat_hot_water_valve',
#  u'heat_wheel_vfd',
#  u'filter',
#  u'mixed_air_filter',
#  u'vfd',
#  u'coil',
#  u'heat_exchanger',
#  u'heating_coil',
#  u'fan',
#  u'exhaust_fan',
#  u'standby_fan',
#  u'supply_fan',
#  u'booster_fan',
#  u'return_fan',
#  u'condensor',
#  u'crac',
#  u'standby_crac_unit',
#  u'emergency_power_off_system',
#  u'fume_hood',
#  u'thermostat',
#  u'pump',
#  u'chilled_water_pump',
#  u'hot_water_pump',
#  u'condenser',
#  u'damper',
#  u'outside_air_damper',
#  u'return_air_damper',
#  u'economizer_damper',
#  u'exhaust_air_damper',
#  u'terminal_unit',
#  u'vav',
#  u'fan_coil_unit',
#  u'boiler',
#  u'valve',
#  u'cooling_valve',
#  u'isolation_valve',
#  u'chilled_water_valve',
#  u'heating_valve',
#  u'domestic_hot_water_valve',
#  u'reheat_valve',
#  u'space_heater',
#  u'economizer',
#  u'energy_storage',
#  u'battery',
#  u'thermal_energy_storage',
#  u'lighting_system',
#  u'weather',
#  u'basement',
#  u'roof',
#  u'outside',
#  u'space',
#  u'zone',
#  u'hvac_zone',
#  u'lighting_zone',
#  u'building',
#  u'wing',
#  u'city',
#  u'room',
#  u'server_room',
#  u'laboratory',
#  u'cold_box',
#  u'freezer',
#  u'environment_box',
#  u'hot_box',
#  u'floor',
#  u'power',
#  u'motor_power',
#  u'enthalpy',
#  u'outside_air_enthalpy',
#  u'outside_enthalpy',
#  u'return_air_enthalpy',
#  u'direction',
#  u'wind_direction',
#  u'current',
#  u'pv_system_output',
#  u'_pv_current_output',
#  u'load_current',
#  u'motor_current',
#  u'photovoltaic_current_output',
#  u'angle',
#  u'solar_zenith_angle',
#  u'solar_azimuth_angle',
#  u'torque',
#  u'motor_torque',
#  u'dewpoint',
#  u'outside_air_dewpoint',
#  u'return_air_dewpoint',
#  u'co2',
#  u'return_air_co2',
#  u'outside_air_co2',
#  u'speed',
#  u'wind_speed',
#  u'heat_wheel_speed',
#  u'motor_speed',
#  u'piezoelectric',
#  u'supply_fan_piezoelectric',
#  u'exhaust_fan_piezoelectric',
#  u'energy',
#  u'thermal_energy',
#  u'position',
#  u'damper_position',
#  u'temperature',
#  u'water_supply_temperature',
#  u'domestic_hot_water_supply_temperature',
#  u'chilled_water_discharge_temperature',
#  u'drive_temperature',
#  u'heat_exchanger_supply_water_temperature',
#  u'preheat_discharge_air_temperature',
#  u'discharge_air_temperature',
#  u'crac_temperature',
#  u'hot_water_supply_temperature',
#  u'high_temperature_hot_water_supply_temperature',
#  u'medium_temperature_hot_water_supply_temperature',
#  u'outside_air_temperature',
#  u'room_temperature',
#  u'freezer_temperature',
#  u'exhaust_air_temperature',
#  u'cold_box_temperature',
#  u'preheat_supply_air_temperature',
#  u'chilled_water_supply_temperature',
#  u'supply_air_temperature',
#  u'chilled_water_return_temperature',
#  u'hot_box_temperature',
#  u'zone_temperature',
#  u'environment_box_temperature',
#  u'heat_wheel_discharge_air_temperature',
#  u'differential_temperature',
#  u'chilled_water_supply_return_differential_temperature',
#  u'heat_wheel_supply_air_temperature',
#  u'hot_water_return_temperature',
#  u'medium_temperature_hot_water_return_temperature',
#  u'high_temperature_hot_water_return_temperature',
#  u'pressure',
#  u'velocity_pressure',
#  u'discharge_air_velocity_pressure',
#  u'supply_air_velocity_pressure',
#  u'exhaust_air_velocity_pressure',
#  u'differential_pressure',
#  u'filter_differential_pressure',
#  u'hot_water_differential_pressure',
#  u'medium_temperature_hot_water_differential_pressure',
#  u'chilled_water_differential_pressure',
#  u'heat_wheel_differential_pressure',
#  u'static_pressure',
#  u'frequency',
#  u'output_frequency',
#  u'flow',
#  u'air_flow',
#  u'return_air_flow',
#  u'return_fan_air_flow',
#  u'fan_air_flow',
#  u'outside_air_flow',
#  u'supply_air_flow',
#  u'booster_fan_air_flow',
#  u'exhaust_air_flow',
#  u'exhaust_air_stack_flow',
#  u'discharge_air_flow',
#  u'supply_fan_air_flow',
#  u'water_flow',
#  u'chilled_water_supply_flow',
#  u'time',
#  u'run_time',
#  u'running_hour',
#  u'solar_radiance',
#  u'grains',
#  u'outside_air_grains',
#  u'return_air_grains',
#  u'humidity',
#  u'outside_air_humidity',
#  u'return_air_humidity',
#  u'relative_humidity',
#  u'conductivity',
#  u'deionised_water_conductivity',
#  u'voltage',
#  u'dc_bus_voltage',
#  u'heat_wheel_voltage',
#  u'output_voltage',
#  u'battery_voltage',
#  u'vfd_voltage',
#  u'air',
#  u'return_air',
#  u'mixed_air',
#  u'outside_air',
#  u'discharge_air',
#  u'steam',
#  u'water',
#  u'chilled_water',
#  u'di_water',
#  u'hot_water',
#  u'domestic_hot_water',
#  u'medium_temperature_hot_water',
#  u'high_temperature_hot_water',
#  u'deionised_water']

# %%
with open("metadata/%s_sentence_dict.json"%buildingName, "r") as fp:
    sentenceDict = json.load(fp)

# %%
known_label_dict = {
    'nae':'none',
    'n': 'none',
    'ebu': 'building',
    'b': 'identifier', # b could be basement, which is ignored currently.
    'rm':'room',
    'vma':'vav',
    'newline':'none',
    'vnd':'vnd'
}
known_word_list = known_label_dict.keys()

# %%
def ask_expert_labels(sentence):
    # Input: List of words
    # Output: feature list:
    # Human operation: Give labels on the words.
    sliceSize = 2
    featureDict = dict()
    
    nonBrickTagList = ['none', 'identifier', 'network_adapter', 'vnd']

    #for words in rolling_window(sentence, 2):
    #    for word in wo
    print("\nGiven sentence: %s"%sentence)
    labelList = list()
    for word in sentence:
        if re.match('[^0-9a-zA-Z]+', word):
            labelList.append('none')
            continue
        if re.match('\d+', word):
            labelList.append('identifier')
            continue
        if word in known_word_list:
            labelList.append(known_label_dict[word])
            continue
            
            
        while True:
            label = raw_input(str(word)+': \n')
            if label in tagList or label in tagsetList or label in nonBrickTagList:
                labelList.append(label)
                break
            else:
                print("Pick Tag among the following tags: " + str(tagList))
    return labelList

# %%
splitter = lambda x:x.split(' ')
train_sents = list()
for row in zip(rawNameList, rawJcinameList, rawDescList):
    para = list()
    for ele in row:
        para.extend([x for x in ele.split(' ') if x!=''])
        para.append('\n')
    train_sents.append(para)

# %%
# Review labelListDict
reviewedLabelListDict = dict()

for srcid, labelLi
st in labelListDict.items():
    reviewedLabelList = list()
    for word, label in zip(sentenceDict[srcid], labelList):
        x = raw_input(word + "\t" + label)
        if x=='':
            reviewedLabelList.append(label)
        else:
            reviewedLabelList.append(x)
# Out:
#   File "<ipython-input-38-f1b453c5c056>", line 4
#     for srcid, labelLi
#                       ^
# SyntaxError: invalid syntax

# %%
labelFilename = 'metadata/%s_label_dict.json'%buildingName
with open(labelFilename, 'r') as fp:
    labelListDict = json.load(fp)

# %%
labelSampleNum = 20
for i in random.sample(range(0,len(sensorDF)), labelSampleNum):
    srcid = sensorDF.iloc[i].name
    if not srcid in labelListDict.keys():
        labelListDict[srcid] = ask_expert_labels(sentenceDict[srcid])
# Out:
# Given sentence: [u'nae', u'06', u'n', u'2', u'1', u'vma', u'103', u'dmpr', u'pos', u'newline', u'ebu', u'3', u'b', u'.', u'rm', u'-', u'2119', u'.', u'.', u'dmpr', u'-', u'pos', u'newline', u'damper', u'position', u'newline']

# %%
with open(labelFilename, 'w') as fp:
    json.dump(labelListDict,fp)
# Out:
# NameErrorTraceback (most recent call last)
# <ipython-input-15-d9d56531885b> in <module>()
#       3     srcid = sensorDF.iloc[i].name
#       4     if not srcid in labelListDict.keys():
# ----> 5         labelListDict[srcid] = ask_expert_labels(sentenceList[i])
#       6
#       7 with open(labelFilename, 'w') as fp:
#
# NameError: name 'sentenceList' is not defined

# %%
#
#with open(labelFilename, 'w') as fp:
#    json.dump(labelListDict,fp)
